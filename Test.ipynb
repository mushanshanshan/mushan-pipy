# %%
from mushan.models.utmos import utmos
# Out:
# 2023-10-05 20:44:03 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX

# %%
m = utmos()
# Out:
# Using device: cpu
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1XiLi8V4t40gde1oeL0uh7CTIiqupNJHm
# From (redirected): https://drive.google.com/uc?id=1XiLi8V4t40gde1oeL0uh7CTIiqupNJHm&confirm=t&uuid=f9b36437-09a3-4eae-8e1f-d04dc5ec0504
# To: /home/mushan/exp/mushan-pipy/mushan/models/utmos/g_05000000
#   7%|██▊                                   | 92.8M/1.24G [00:14<02:24, 7.91MB/s]

# %%
text = "Our preliminary version of this work was initially published in a conference."
idx = f.text_to_idx(text)

# %%
idx
# Out:
# tensor([  0, 157,   0,  43,   0, 135,   0,  85,   0,  16,   0,  58,   0, 123,
#           0, 102,   0,  54,   0, 156,   0, 102,   0,  55,   0, 102,   0,  56,
#           0, 157,   0,  86,   0, 123,   0,  51,   0,  16,   0,  64,   0, 156,
#           0,  87,   0, 158,   0, 147,   0,  83,   0,  56,   0,  16,   0, 138,
#           0,  64,   0,  16,   0,  81,   0, 102,   0,  61,   0,  16,   0,  65,
#           0, 156,   0,  87,   0, 158,   0,  53,   0,  16,   0,  65,   0, 138,
#           0,  68,   0,  16,   0, 102,   0,  56,   0, 156,   0, 102,   0, 131,
#           0,  83,   0,  54,   0,  51,   0,  16,   0,  58,   0, 156,   0, 138,
#           0,  44,   0,  54,   0, 102,   0, 131,   0,  62,   0,  16,   0, 102,
#           0,  56,   0,  16,   0,  70,   0,  16,   0,  53,   0, 156,   0,  69,
#           0, 158,   0,  56,   0,  48,   0, 123,   0,  83,   0,  56,   0,  61,
#           0,   4,   0])
